# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **False.** Multiplicative models are used when the seasonal effect is proportional to the trend.
#
# 2. **True.** The regression approach removes the trend by fitting a line to the data and then subtracting the line from the data. The MA approach removes the trend by averaging the data over a fixed period.
#
# 3. **True.**
#
# 4. **True.**
#
# 5. **True.** As the moving average cannot be calculated for points that do not have enough data points around them.
#
# 6. **True.**
